# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("adult_dataset.csv",sep=",")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (48842, 15)

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_male = df[df["gender"]=="Male"]
df_male
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 5       34    Private  198693          10th                6
# ...    ...        ...     ...           ...              ...
# 48834   32    Private  116138       Masters               14
# 48835   53    Private  321865       Masters               14
# 48836   22    Private  310152  Some-college               10
# 48838   40    Private  154374       HS-grad                9
# 48840   22    Private  201490       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 0           Never-married  Machine-op-inspct      Own-child
# 1      Married-civ-spouse    Farming-fishing        Husband
# ...

# %%
df_female = df[df["gender"]=="Female"]
df_female
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 4       18             ?  103497  Some-college               10
# 8       24       Private  369667  Some-college               10
# 12      26       Private   82091       HS-grad                9
# 17      43       Private  128354       HS-grad                9
# 18      37       Private   60548       HS-grad                9
# ...    ...           ...     ...           ...              ...
# 48827   37       Private  198216    Assoc-acdm               12
# 48830   43     State-gov  255835  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48839   58       Private  151910       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 4           Never-married                  ?       Own-child  White  Female
# ...

# %%
df["native-country"].unique()
# Out:
# array(['United-States', '?', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
df_country_India = df[df["native-country"] == "India"]
df_country_India
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 398     36    Private  116358       Masters               14
# 564     26    Private  341672  Some-college               10
# 1101    55    Private  176219     Bachelors               13
# 1556    33  State-gov  150688     Doctorate               16
# 1593    54          ?  120781     Doctorate               16
# ...    ...        ...     ...           ...              ...
# 46433   48    Private  119471     Doctorate               16
# 47114   25    Private  110978    Assoc-acdm               12
# 47152   26    Private  160261       Masters               14
# 47608   38  State-gov  125499     Bachelors               13
# 47638   23    Private  143003       Masters               14
#
#               marital-status         occupation    relationship  \
# 398       Married-civ-spouse    Exec-managerial         Husband
# 564            Never-married       Adm-clerical  Other-relative
# ...

# %%
df_merge_male_india = pd.concat([df_male,df_country_India])
df_merge_male_india
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 5       34    Private  198693          10th                6
# ...    ...        ...     ...           ...              ...
# 46433   48    Private  119471     Doctorate               16
# 47114   25    Private  110978    Assoc-acdm               12
# 47152   26    Private  160261       Masters               14
# 47608   38  State-gov  125499     Bachelors               13
# 47638   23    Private  143003       Masters               14
#
#            marital-status         occupation   relationship  \
# 0           Never-married  Machine-op-inspct      Own-child
# 1      Married-civ-spouse    Farming-fishing        Husband
# ...

# %%
df_age = df.sort_values("age")
df_age
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 32598   17           Private  133449           9th                5
# 29817   17  Self-emp-not-inc  181317          10th                6
# 36580   17           Private  147339          10th                6
# 26409   17           Private  186677          11th                7
# 19520   17                 ?  110998  Some-college               10
# ...    ...               ...     ...           ...              ...
# 12446   90           Private  347074  Some-college               10
# 19172   90           Private  171956  Some-college               10
# 8982    90           Private  225063       HS-grad                9
# 28277   90           Private   40388     Bachelors               13
# 899     90           Private  149069    Assoc-acdm               12
#
#            marital-status         occupation   relationship  \
# 32598       Never-married      Other-service      Own-child
# ...

# %%
df_transpose = df.transpose()

# %%
df_transpose
# Out:
#                              0                   1                   2      \
# age                             25                  38                  28
# workclass                  Private             Private           Local-gov
# fnlwgt                      226802               89814              336951
# education                     11th             HS-grad          Assoc-acdm
# educational-num                  7                   9                  12
# marital-status       Never-married  Married-civ-spouse  Married-civ-spouse
# occupation       Machine-op-inspct     Farming-fishing     Protective-serv
# relationship             Own-child             Husband             Husband
# race                         Black               White               White
# gender                        Male                Male                Male
# capital-gain                     0                   0                   0
# ...

# %%
df_melt = pd.melt(df,id_vars=["education","occupation"],value_name="value",var_name="Metric")
df_melt
# Out:
#            education         occupation  Metric  value
# 0               11th  Machine-op-inspct     age     25
# 1            HS-grad    Farming-fishing     age     38
# 2         Assoc-acdm    Protective-serv     age     28
# 3       Some-college  Machine-op-inspct     age     44
# 4       Some-college                  ?     age     18
# ...              ...                ...     ...    ...
# 634941    Assoc-acdm       Tech-support  income  <=50K
# 634942       HS-grad  Machine-op-inspct  income   >50K
# 634943       HS-grad       Adm-clerical  income  <=50K
# 634944       HS-grad       Adm-clerical  income  <=50K
# 634945       HS-grad    Exec-managerial  income   >50K
#
# [634946 rows x 4 columns]

# %%
df_cleaned = df[(df['workclass'] != '?') & (df['occupation'] != '?')]
df_cast = pd.pivot_table(df_cleaned,index=["workclass","occupation"],values=["hours-per-week","capital-loss","capital-gain"])
df_cast
# Out:
#                                capital-gain  capital-loss  hours-per-week
# workclass   occupation
# Federal-gov Adm-clerical         498.827515    108.505133       40.429158
#             Armed-Forces         486.533333    125.800000       41.600000
#             Craft-repair         466.225806     97.559140       40.892473
#             Exec-managerial     1507.126866     88.414179       42.264925
#             Farming-fishing     1386.222222      0.000000       40.000000
# ...                                     ...           ...             ...
# Without-pay Handlers-cleaners   2208.000000      0.000000       50.000000
#             Machine-op-inspct      0.000000    943.500000       32.500000
#             Other-service          0.000000      0.000000       32.500000
#             Sales                  0.000000      0.000000       45.000000
#             Transport-moving    2414.000000      0.000000       20.000000
#
# [83 rows x 3 columns]
